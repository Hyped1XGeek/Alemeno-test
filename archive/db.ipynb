# %%
import psycopg2

# %%
conn = psycopg2.connect("dbname=test user=postgres password='Anand123*'")

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM table")
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cur.execute("SELECT * FROM table")
#
# SyntaxError: syntax error at or near "table"
# LINE 1: SELECT * FROM table
#                       ^

# %%
psycopg2.connect("dbname='cookiebox' user='postgres' host='localhost' password='Anand123*'")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 psycopg2.connect("dbname='cookiebox' user='postgres' host='localhost' password='Anand123*'")
#
# File c:\System-Data-Local\Compilers\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "cookiebox" does not exist
